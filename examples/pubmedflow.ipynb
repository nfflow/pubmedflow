# %%
from pubmedflow import LazyPubmed

pb        = LazyPubmed()
df_result = pb.pubmed_search(query         = 'Chronic',
                             key           = "your_ncbi_api_key",
                             max_documents = 10,
                             download_pdf  = True, 
                             scihub        = False)
# Out:
# 2022-06-28 09:51:35 SILTP-11022.local metapub.config[24952] WARNING NCBI_API_KEY was not set.
# -------------------------------------------
#
#  Fetching total documents -> 10..
#
# -------------------------------------------
#   0%|                                                                                                       | 0/1 [00:00<?, ?it/s]
# Getting this URL: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&api_key=3804670b81fdf67466ca3e8043146fc54708&retmax=10&retmode=xml&query_key=1&webenv=MCID_62ba81d25f19e924b92bd9ac&retstart=0
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 64.28it/s]
# Total pdf downloading : 10..
# ...
#   0%|                                                                                                       | 0/2 [00:00<?, ?it/s]2022-06-28 09:52:12 SILTP-11022.local pdfminer3.pdfdocument[24952] INFO xref found: pos=b'116'
# ...

# %%
df_result
# Out:
#                                                title      issue  \
# 0  Assessing the experience of person-centred coo...      25(3)
# 1  Association Between Systolic Blood Pressure Va...     11(11)
# 2  Comorbidity progression patterns of major chro...        NaN
# 3  A Review of Laser Therapy and Low-Intensity Ul...      26(1)
# 4  Patients' and healthcare providers' perception...      22(1)
# 5  A Preliminary Study of Provider Burden in the ...     22(11)
# 6  "A little bit of a guidance and a little bit o...     43(23)
# 7  Chronic disease health literacy in First Natio...  30(17-18)
# 8  Patient Perceptions of Physician Burden in the...      22(9)
# 9  The relationship between the perception of chr...        NaN
#
#                pages                                           abstract  \
# 0          1069-1080  BACKGROUND\nCountries are adapting their healt...
# 1            e025513  Background Whether visit-to-visit systolic blo...
# ...
